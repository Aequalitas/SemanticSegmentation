# %%
# Semantic Segmentation with Tensorflow
# by Franz Weidmann www.github.com/Aequalitas
# %matplotlib notebook

import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
import os
import numpy as np
import sys
import json

from data import Data
from graph import buildGraph
from train import doTrain
from predict import predict
from evaluate import evaluate
from runLengthEncoding import runLenEncodeTestSet

MODE = "train"
# load config for tensorflow procedure from json
config = json.load(open("nets/refineNetConfig.json"))
# load data object initially which provides training and test data loader
data = Data("../data/"+config["dataset"]+"/configData"+config["dataset"]+".json")

if MODE == "serialize":
    if data.config["fileName"] != "":
        np.save(data.config["path"]+data.config["fileName"], data.getDataset(flipH=False))
    else:
        print("You have to set a filename for the serialized file in the config file!")
        exit()

# create the tensorflow graph and logging
graph = buildGraph(data, config)


os.environ["CUDA_VISIBLE_DEVICES"]=config["gpu"]
tf.logging.set_verbosity(tf.logging.INFO)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    modelFileName = "../models/model"+str(data.config["x"])+str(data.config["y"])+data.config["name"]+config["neuralNetwork"]+".ckpt"
    try:
        graph["saver"].restore(sess, modelFileName)
    except:
        print("No valid checkpoint found")

    accuracySum = 0

    if MODE == "train":
        print("Starting training...")

        for e in range(1, config["epochs"]+1):
            accuracySum += doTrain(e, sess, graph, config, data, modelFileName)
            #print("\nMean Accuracy for ",e," epochs: ", (accuracySum/(e)))
            save_path = graph["saver"].save(sess, modelFileName)
            print("\nModel saved in file: %s" % save_path)

        save_path = graph["saver"].save(sess, modelFileName)
        print("Model saved in file: %s" % save_path)

    elif MODE == "eval":
        evaluate(sess, config, data, graph)
    elif MODE == "predict":
        predict(sess, config, data, graph)
    elif MODE == "runLenEncode":
        runLenEncodeTestSet(sess, config, data, graph)
# Out:
# Finished loading dataset...
# INFO:tensorflow:Restoring parameters from ../models/model12896SeagrassrefineNet.ckpt
# Starting training...
# [0 0 0 ... 0 0 0]: 101/8446 || loss:6.705 || train_accuracy:11.068% || time 1 step with batch of 1: 0.041
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9AB74D57F0>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5668>
# [0 0 0 ... 0 1 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5828>
# [0 0 0 ... 1 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5630>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5668>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF56A0>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF57F0>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5780>
# [0 0 0 ... 1 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5630>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5828>
# [0 1 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF57F0>
# [0 0 0 ... 1 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF56A0>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5828>
# [0 0 0 ... 1 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5630>
# [0 1 0 ... 1 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5828>
# [0 0 0 ... 1 1 1]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF56A0>
# [0 0 0 ... 1 1 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5630>
# [0 0 1 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5860>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5780>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5828>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF57F0>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF57B8>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5630>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF56A0>
# [0 0 0 ... 1 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF57B8>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5780>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF57F0>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5668>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5780>
# [1 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF56A0>
# [0 1 0 ... 0 1 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5828>
# [0 0 0 ... 0 1 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF57F0>
# [0 0 1 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5668>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5780>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF56A0>
# [0 0 0 ... 1 1 1]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5630>
# [0 0 0 ... 1 1 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5828>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF57F0>
# [0 0 1 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5668>
# [0 0 0 ... 1 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5780>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF56A0>
# [1 0 0 ... 0 1 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5668>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5828>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF56A0>
# [0 0 0 ... 0 0 1]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5630>
# [1 0 0 ... 1 0 1]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5668>
# [0 0 0 ... 1 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF56A0>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF57B8>
# [0 1 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5828>
# [0 0 0 ... 0 1 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF57F0>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5630>
# [1 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5668>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF56A0>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF57B8>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5828>
# [0 1 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF57F0>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5860>
# [0 0 0 ... 1 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5668>
# [0 0 0 ... 1 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5828>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF56A0>
# validation_accuracy: 18.183
#
# Model saved in file: ../models/model12896SeagrassrefineNet.ckpt
# [0 0 0 ... 0 1 0]: 101/8446 || loss:0.568 || train_accuracy:18.091% || time 1 step with batch of 1: 0.042
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5860>
# [0 0 0 ... 1 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5630>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5BE0>
# [0 0 1 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5898>
# [0 1 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5CF8>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5860>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5630>
# [0 0 0 ... 0 1 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5A20>
# [0 1 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5CF8>
# [0 0 0 ... 0 1 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5BE0>
# [0 1 0 ... 0 1 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5A20>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5B00>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF59E8>
# [1 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5A20>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5668>
# [0 0 0 ... 1 1 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF59E8>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5B00>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5CF8>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5898>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5A20>
# [0 1 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF59E8>
# [0 1 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5CF8>
# [0 0 0 ... 0 0 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5860>
# [0 0 0 ... 0 1 0]
# <PIL.Image.Image image mode=RGB size=128x96 at 0x7F9ACDEF5898>
